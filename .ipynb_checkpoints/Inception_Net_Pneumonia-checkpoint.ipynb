# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Check for GPU and allocate a fixed amount of GPU mem
gpus = tf.config.experimental.list_physical_devices("GPU")
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])
  except RuntimeError as e:
    print(e)
else:
    print("WARNING: NO GPU FOUND")

# %%
from pathlib import Path

# Current Working Directory
base_path = Path('.')
data_path = base_path / 'data'

# First Data Set
pneumonia_data = data_path / 'pneumonia_binary_data1'
pneumonia_train_path = pneumonia_data / 'train'
pneumonia_test_path = pneumonia_data / 'test'

# RSNA Data Set
rsna_data_path = data_path / 'rsna_data_scaled_256'
rsna_train_path = rsna_data_path / 'train'

# Covid Data Set
covid_data_path = data_path / 'covid_data'
covid_train_path = covid_data_path / 'train'
covid_validation_path = covid_data_path / 'validation2'

# %%
image_shape = (128, 128, 1)
batch_size = 16

# %%
# Image Augmentation Parameters
aug_param = {
    'rotation_range' : 20, # rotate the image 20 degrees
    'width_shift_range' : 0.10, # Shift the pic width by a max of 5%
    'height_shift_range' : 0.10, # Shift the pic height by a max of 5%
    'rescale' : 1/255, # Rescale the image by normalzing it.
    'shear_range' : 0.1, # Shear means cutting away part of the image (max 10%)
    'zoom_range' : 0.1, # Zoom in by 10% max
    'brightness_range' : [0.8,1.2], # Vary brightness between range +-
    'horizontal_flip' : True,
    'fill_mode' : 'nearest'
}

# %%
image_gen = ImageDataGenerator(aug_param)
image_gen_w_split = ImageDataGenerator(aug_param, validation_split=0.2)

# %%
# Generator Parameters
gen_param = {
    'target_size' : image_shape[:2],
    'color_mode' : 'grayscale',
    'batch_size' : batch_size,
    'class_mode' : 'binary'
}

# %%
# First Data Set generator
pneumonia_train_gen = image_gen.flow_from_directory(pneumonia_train_path, gen_param)
pneumonia_test_gen = image_gen.flow_from_directory(pneumonia_test_path, gen_param, shuffle=False)

# RSNA Data Set generator
rsna_train_gen = image_gen_w_split.flow_from_directory(rsna_train_path, gen_param, subset='training')
rsna_test_gen = image_gen_w_split.flow_from_directory(rsna_train_path, gen_param, subset='validation', shuffle=False)

# Covid Data Set generator
covid_train_gen = image_gen_w_split.flow_from_directory(covid_train_path, gen_param, subset='training')
covid_test_gen = image_gen_w_split.flow_from_directory(covid_train_path, gen_param, subset='validation', shuffle=False)
covid_validation2_gen = image_gen.flow_from_directory(covid_validation_path, gen_param, shuffle=False)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 21348 images belonging to 2 classes.
# Found 5336 images belonging to 2 classes.
# Found 2149 images belonging to 2 classes.
# Found 537 images belonging to 2 classes.
# Found 134 images belonging to 2 classes.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Activation, Flatten, Dense
from tensorflow.keras.layers import Conv2D, SeparableConv2D, AveragePooling2D, DepthwiseConv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization, Dropout, concatenate
from tensorflow.keras.backend import binary_crossentropy, mean

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
        
def weighted_binary_crossentropy(y_true, y_pred):
        weight_normal = 0.9
        weight_pneumonia = 1 - weight_normal
        b_ce = binary_crossentropy(y_true, y_pred)

        weight_vector = y_true * weight_pneumonia + (1. - y_true) * weight_normal
        weighted_b_ce = weight_vector * b_ce
        
        return mean(weighted_b_ce)
        
early_stop = EarlyStopping(monitor='val_loss',patience=10)

# %%
model_input = Input(shape=image_shape)

# Feature indentification and reduction
extraction_layer_1 = Conv2D(32, (3,3), activation='relu', padding='same')(model_input)
extraction_layer_1 = Conv2D(64, (3,3), activation='relu', padding='same')(extraction_layer_1)

f1 = Conv2D(96, (3,3), activation='relu', strides=(2,2), padding='same')(extraction_layer_1)

f2 = MaxPooling2D((3,3), strides=(2,2), padding='same')(extraction_layer_1)

reduction_layer_0 = concatenate([f1, f2])

z1 = Conv2D(64, (1,1), activation='relu')(reduction_layer_0)

z2 = Conv2D(32, (1,1), activation='relu')(reduction_layer_0)
z2 = Conv2D(48, (3,3), activation='relu', padding='same')(z2)

z3 = Conv2D(32, (1,1), activation='relu')(reduction_layer_0)
z3 = Conv2D(48, (5,5), activation='relu', padding='same')(z3)

inception_layer_0 = concatenate([z1,z2,z3])

a1 = Conv2D(128, (3,3), activation='relu', strides=(2,2), padding='same')(inception_layer_0)

a2 = MaxPooling2D((3,3), strides=(2,2), padding='same')(inception_layer_0)

reduction_layer_1 = concatenate([a1, a2])

d1 = Conv2D(64, (1,1), activation='relu')(reduction_layer_1)

d2 = Conv2D(64, (1,1), activation='relu')(reduction_layer_1)
d2 = Conv2D(128, (3,3), activation='relu', padding='same')(d2)

d3 = Conv2D(32, (1,1), activation='relu')(reduction_layer_1)
d3 = Conv2D(64, (5,5), activation='relu', padding='same')(d3)

inception_layer_1 = concatenate([d1,d2,d3])

# 2nd Reduction Layer
b1 = Conv2D(128, (3,3), activation='relu', strides=(2,2))(inception_layer_1)
b1 = BatchNormalization()(b1)

b2 = MaxPooling2D((3,3), strides=(2,2))(inception_layer_1)

reduction_layer_2 = concatenate([b1, b2])

x1 = Conv2D(128, (1,1), activation='relu')(reduction_layer_2)

x2 = Conv2D(32, (1,1), activation='relu')(reduction_layer_2)
x2 = Conv2D(64, (3,3), activation='relu', padding='same')(x2)

x3 = Conv2D(32, (1,1), activation='relu')(reduction_layer_2)
x3 = Conv2D(64, (5,5), activation='relu', padding='same')(x3)

inception_layer_2 = concatenate([x1, x2, x3])

c1 = Conv2D(160, (3,3), activation='relu', strides=(2,2))(inception_layer_2)
c1 = BatchNormalization()(c1)

c2 = MaxPooling2D((3,3), strides=(2,2))(inception_layer_2)

reduction_layer_3 = concatenate([c1, c2])

e1 = Conv2D(160, (1,1), activation='relu')(reduction_layer_3)
e1 = BatchNormalization()(e1)

e2 = Conv2D(96, (1,1), activation='relu')(reduction_layer_3)
e2 = Conv2D(160, (3,3), activation='relu', padding='same')(e2)
e2 = BatchNormalization()(e2)

e3 = Conv2D(64, (1,1), activation='relu')(reduction_layer_3)
e3 = Conv2D(128, (5,5), activation='relu', padding='same')(e3)
e3 = BatchNormalization()(e3)

inception_layer_3 = concatenate([e1,e2,e3])

model = AveragePooling2D((7, 7))(inception_layer_3)

model = Flatten()(model)

model = Dense(160)(model)

model = Dropout(0.5)(model, training=True)

model = Activation('relu')(model)

model_output = Dense(1, activation='sigmoid')(model)

model = Model(inputs=model_input, outputs=model_output)


model.compile(loss=weighted_binary_crossentropy,
              optimizer='RMSProp',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_338 (Conv2D)             (None, 128, 128, 32) 320         input_14[0][0]
# __________________________________________________________________________________________________
# conv2d_339 (Conv2D)             (None, 128, 128, 64) 18496       conv2d_338[0][0]
# __________________________________________________________________________________________________
# conv2d_340 (Conv2D)             (None, 64, 64, 96)   55392       conv2d_339[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_52 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_339[0][0]
# __________________________________________________________________________________________________
# concatenate_104 (Concatenate)   (None, 64, 64, 160)  0           conv2d_340[0][0]
#                                                                  max_pooling2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, 64, 64, 32)   5152        concatenate_104[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, 64, 64, 32)   5152        concatenate_104[0][0]
# __________________________________________________________________________________________________
# conv2d_341 (Conv2D)             (None, 64, 64, 64)   10304       concatenate_104[0][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, 64, 64, 48)   13872       conv2d_342[0][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, 64, 64, 48)   38448       conv2d_344[0][0]
# __________________________________________________________________________________________________
# concatenate_105 (Concatenate)   (None, 64, 64, 160)  0           conv2d_341[0][0]
#                                                                  conv2d_343[0][0]
#                                                                  conv2d_345[0][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, 32, 32, 128)  184448      concatenate_105[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_53 (MaxPooling2D) (None, 32, 32, 160)  0           concatenate_105[0][0]
# __________________________________________________________________________________________________
# concatenate_106 (Concatenate)   (None, 32, 32, 288)  0           conv2d_346[0][0]
#                                                                  max_pooling2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, 32, 32, 64)   18496       concatenate_106[0][0]
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, 32, 32, 32)   9248        concatenate_106[0][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, 32, 32, 64)   18496       concatenate_106[0][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, 32, 32, 128)  73856       conv2d_348[0][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, 32, 32, 64)   51264       conv2d_350[0][0]
# __________________________________________________________________________________________________
# concatenate_107 (Concatenate)   (None, 32, 32, 256)  0           conv2d_347[0][0]
#                                                                  conv2d_349[0][0]
#                                                                  conv2d_351[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 15, 15, 128)  295040      concatenate_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 15, 15, 128)  512         conv2d_352[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_54 (MaxPooling2D) (None, 15, 15, 256)  0           concatenate_107[0][0]
# __________________________________________________________________________________________________
# concatenate_108 (Concatenate)   (None, 15, 15, 384)  0           batch_normalization_72[0][0]
#                                                                  max_pooling2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 15, 15, 32)   12320       concatenate_108[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 15, 15, 32)   12320       concatenate_108[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 15, 15, 128)  49280       concatenate_108[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 15, 15, 64)   18496       conv2d_354[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 15, 15, 64)   51264       conv2d_356[0][0]
# __________________________________________________________________________________________________
# concatenate_109 (Concatenate)   (None, 15, 15, 256)  0           conv2d_353[0][0]
#                                                                  conv2d_355[0][0]
#                                                                  conv2d_357[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 7, 7, 160)    368800      concatenate_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 7, 7, 160)    640         conv2d_358[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_55 (MaxPooling2D) (None, 7, 7, 256)    0           concatenate_109[0][0]
# __________________________________________________________________________________________________
# concatenate_110 (Concatenate)   (None, 7, 7, 416)    0           batch_normalization_73[0][0]
#                                                                  max_pooling2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_360 (Conv2D)             (None, 7, 7, 96)     40032       concatenate_110[0][0]
# __________________________________________________________________________________________________
# conv2d_362 (Conv2D)             (None, 7, 7, 64)     26688       concatenate_110[0][0]
# __________________________________________________________________________________________________
# conv2d_359 (Conv2D)             (None, 7, 7, 160)    66720       concatenate_110[0][0]
# __________________________________________________________________________________________________
# conv2d_361 (Conv2D)             (None, 7, 7, 160)    138400      conv2d_360[0][0]
# __________________________________________________________________________________________________
# conv2d_363 (Conv2D)             (None, 7, 7, 128)    204928      conv2d_362[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 7, 7, 160)    640         conv2d_359[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 7, 7, 160)    640         conv2d_361[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 7, 7, 128)    512         conv2d_363[0][0]
# __________________________________________________________________________________________________
# concatenate_111 (Concatenate)   (None, 7, 7, 448)    0           batch_normalization_74[0][0]
#                                                                  batch_normalization_75[0][0]
#                                                                  batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 1, 1, 448)    0           concatenate_111[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 448)          0           average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 160)          71840       flatten_13[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 160)          0           dense_26[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 160)          0           dropout_10[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            161         activation_7[0][0]
# ==================================================================================================
# Total params: 1,862,177
# Trainable params: 1,860,705
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
results = model.fit(covid_train_image_gen,epochs=30,
                              validation_data=covid_test_image_gen,
                               callbacks=[ReduceLROnPlateau(), 
                                          ModelCheckpoint('checkpoint.h5',save_best_only=True, monitor='val_accuracy')])
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 135 steps, validate for 34 steps
# Epoch 1/30
# 135/135 [==============================] - 35s 259ms/step - loss: 0.1579 - accuracy: 0.6366 - val_loss: 5.5283 - val_accuracy: 0.5009
# Epoch 2/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.1210 - accuracy: 0.6873 - val_loss: 22.3417 - val_accuracy: 0.5009
# Epoch 3/30
# 135/135 [==============================] - 33s 241ms/step - loss: 0.0957 - accuracy: 0.7655 - val_loss: 3.7533 - val_accuracy: 0.5251
# Epoch 4/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0990 - accuracy: 0.7604 - val_loss: 0.1654 - val_accuracy: 0.5531
# Epoch 5/30
# 135/135 [==============================] - 32s 240ms/step - loss: 0.0896 - accuracy: 0.7873 - val_loss: 3.7048 - val_accuracy: 0.5009
# Epoch 6/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0820 - accuracy: 0.8176 - val_loss: 1.1667 - val_accuracy: 0.6965
# Epoch 7/30
# 135/135 [==============================] - 32s 238ms/step - loss: 0.0767 - accuracy: 0.8353 - val_loss: 4.7779 - val_accuracy: 0.5084
# Epoch 8/30
# 135/135 [==============================] - 32s 237ms/step - loss: 0.0704 - accuracy: 0.8278 - val_loss: 3.2318 - val_accuracy: 0.5009
# Epoch 9/30
# 135/135 [==============================] - 32s 237ms/step - loss: 0.0741 - accuracy: 0.8353 - val_loss: 10.3269 - val_accuracy: 0.5009
# Epoch 10/30
# 135/135 [==============================] - 32s 238ms/step - loss: 0.0761 - accuracy: 0.8227 - val_loss: 0.3206 - val_accuracy: 0.5475
# Epoch 11/30
# 135/135 [==============================] - 32s 240ms/step - loss: 0.0794 - accuracy: 0.8036 - val_loss: 0.1512 - val_accuracy: 0.8827
# Epoch 12/30
# 135/135 [==============================] - 33s 244ms/step - loss: 0.0674 - accuracy: 0.8557 - val_loss: 8.8878 - val_accuracy: 0.5009
# Epoch 13/30
# 135/135 [==============================] - 32s 240ms/step - loss: 0.0772 - accuracy: 0.8190 - val_loss: 0.3040 - val_accuracy: 0.5009
# Epoch 14/30
# 135/135 [==============================] - 33s 242ms/step - loss: 0.0682 - accuracy: 0.8418 - val_loss: 3.3114 - val_accuracy: 0.5307
# Epoch 15/30
# 135/135 [==============================] - 33s 243ms/step - loss: 0.0783 - accuracy: 0.8195 - val_loss: 4.8582 - val_accuracy: 0.5009
# Epoch 16/30
# 135/135 [==============================] - 33s 241ms/step - loss: 0.0717 - accuracy: 0.8302 - val_loss: 0.4473 - val_accuracy: 0.8007
# Epoch 17/30
# 135/135 [==============================] - 33s 242ms/step - loss: 0.0672 - accuracy: 0.8474 - val_loss: 9.4920 - val_accuracy: 0.5009
# Epoch 18/30
# 135/135 [==============================] - 32s 240ms/step - loss: 0.0653 - accuracy: 0.8469 - val_loss: 0.2157 - val_accuracy: 0.5140
# Epoch 19/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0669 - accuracy: 0.8432 - val_loss: 3.4165 - val_accuracy: 0.5028
# Epoch 20/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0623 - accuracy: 0.8576 - val_loss: 2.2399 - val_accuracy: 0.5382
# Epoch 21/30
# 135/135 [==============================] - 32s 237ms/step - loss: 0.0640 - accuracy: 0.8544 - val_loss: 0.1556 - val_accuracy: 0.8194
# Epoch 22/30
# 135/135 [==============================] - 32s 240ms/step - loss: 0.0580 - accuracy: 0.8855 - val_loss: 0.0634 - val_accuracy: 0.8045
# Epoch 23/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0487 - accuracy: 0.8874 - val_loss: 0.0489 - val_accuracy: 0.8529
# Epoch 24/30
# 135/135 [==============================] - 32s 238ms/step - loss: 0.0550 - accuracy: 0.8916 - val_loss: 0.0489 - val_accuracy: 0.8585
# Epoch 25/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0543 - accuracy: 0.8841 - val_loss: 0.0895 - val_accuracy: 0.9311
# Epoch 26/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0524 - accuracy: 0.8893 - val_loss: 0.0547 - val_accuracy: 0.8194
# Epoch 27/30
# 135/135 [==============================] - 32s 240ms/step - loss: 0.0510 - accuracy: 0.8916 - val_loss: 0.0523 - val_accuracy: 0.9013
# Epoch 28/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0503 - accuracy: 0.8827 - val_loss: 0.0540 - val_accuracy: 0.8920
# Epoch 29/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0499 - accuracy: 0.8920 - val_loss: 0.0559 - val_accuracy: 0.8976
# Epoch 30/30
# 135/135 [==============================] - 32s 239ms/step - loss: 0.0460 - accuracy: 0.8972 - val_loss: 0.0544 - val_accuracy: 0.8957

# %%
model.save('curr_model.h5')

losses = pd.DataFrame(model.history.history)

# %%
from tensorflow.keras.models import load_model
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import classification_report,confusion_matrix

def get_test_data(dataset):
    if dataset == 'rsna':
        return rsna_test_image_gen
    if dataset == 'original':
        return test_image_gen
    if dataset == 'covid':
        return covid_test_image_gen
    if dataset == 'validation1':
        return covid_validation_1_image_gen
    if dataset == 'validation2':
        return covid_validation_2_image_gen

def print_stats(model, dataset):
    testX = get_test_data(dataset)
    testY = testX.classes
    
    model.evaluate(testX)
    
    # Processing probabilities
    pred_probabilities = model.predict(testX)
    predictions = pred_probabilities > 0.5
    
    for i in range(len(pred_probabilities)):
        if pred_probabilities[i] > 0.7:
            pred_probabilities[i] = 2
        elif pred_probabilities[i] > 0.3:
            pred_probabilities[i] = 1
        else:
            pred_probabilities[i] = 0
    
    # Only for binary classification
    print(classification_report(testY, predictions))
    
    # Print Confusion Matrix
#     cm  = confusion_matrix(testY, pred_probabilities)[:-1]
    cm  = confusion_matrix(testY, predictions)
    plt.figure()
    plt.rcParams['font.size'] = 26.0
    plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues)
    plt.xticks(range(2), ['Normal', 'Pneumonia'], fontsize=20)
    plt.yticks(range(2), ['Normal', 'Pneumonia'], fontsize=20)
    plt.show()

# %%
best_model = load_model('checkpoint.h5'
                        , custom_objects={'weighted_binary_crossentropy':weighted_binary_crossentropy}
                       )

print_stats(best_model, 'covid')
print_stats(best_model, 'original')
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 34/34 [==============================] - 7s 191ms/step - loss: 0.0888 - accuracy: 0.9292
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       268
#            1       0.94      0.90      0.92       269
#
#     accuracy                           0.92       537
#    macro avg       0.92      0.92      0.92       537
# weighted avg       0.92      0.92      0.92       537
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 40/40 [==============================] - 6s 149ms/step - loss: 0.4372 - accuracy: 0.8072
#               precision    recall  f1-score   support
#
#            0       0.80      0.63      0.71       234
#            1       0.81      0.91      0.86       404
#
#     accuracy                           0.81       638
#    macro avg       0.81      0.77      0.78       638
# weighted avg       0.81      0.81      0.80       638

# %%
print_stats(curr_model, 'validation1')
print_stats(curr_model, 'validation2')
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 28/28 [==============================] - 7s 255ms/step - loss: 0.6474 - accuracy: 0.5849
#               precision    recall  f1-score   support
#
#            0       0.64      0.69      0.66       234
#            1       0.60      0.54      0.57       202
#
#     accuracy                           0.62       436
#    macro avg       0.62      0.62      0.62       436
# weighted avg       0.62      0.62      0.62       436
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 9/9 [==============================] - 4s 461ms/step - loss: 0.5034 - accuracy: 0.6493
#               precision    recall  f1-score   support
#
#            0       0.64      0.81      0.72        67
#            1       0.74      0.55      0.63        67
#
#     accuracy                           0.68       134
#    macro avg       0.69      0.68      0.67       134
# weighted avg       0.69      0.68      0.67       134

# %%
print_stats(best_model, 'validation1')
print_stats(best_model, 'validation2')
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 28/28 [==============================] - 7s 258ms/step - loss: 0.5722 - accuracy: 0.5894
#               precision    recall  f1-score   support
#
#            0       0.60      0.69      0.64       234
#            1       0.56      0.47      0.51       202
#
#     accuracy                           0.58       436
#    macro avg       0.58      0.58      0.57       436
# weighted avg       0.58      0.58      0.58       436
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 9/9 [==============================] - 4s 460ms/step - loss: 0.3560 - accuracy: 0.6269
#               precision    recall  f1-score   support
#
#            0       0.61      0.76      0.68        67
#            1       0.69      0.52      0.59        67
#
#     accuracy                           0.64       134
#    macro avg       0.65      0.64      0.64       134
# weighted avg       0.65      0.64      0.64       134

# %%
curr_model = load_model('curr_model.h5'
                        , custom_objects={'weighted_binary_crossentropy':weighted_binary_crossentropy}
                       )

print_stats(curr_model, 'covid')
print_stats(curr_model, 'original')
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 34/34 [==============================] - 6s 191ms/step - loss: 0.0523 - accuracy: 0.8994
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.90       268
#            1       0.98      0.81      0.89       269
#
#     accuracy                           0.90       537
#    macro avg       0.91      0.90      0.89       537
# weighted avg       0.91      0.90      0.89       537
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 40/40 [==============================] - 6s 151ms/step - loss: 0.2388 - accuracy: 0.8417
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80       234
#            1       0.90      0.84      0.87       404
#
#     accuracy                           0.84       638
#    macro avg       0.83      0.84      0.83       638
# weighted avg       0.85      0.84      0.84       638

# %%
losses[['accuracy','val_accuracy']].plot()

# %%
best_predictions = best_model.predict(covid_image_gen)
curr_predictions = curr_model.predict(covid_image_gen)

# %%
best_predictions = best_predictions > 0.5
curr_predictions = curr_predictions > 0.5

# %%
print(best_predictions)
print(curr_predictions)
# Out:
# [[ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# [[ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]]

# %%
sample_image_path_1 = test_path / 'NORMAL' / 'NORMAL2-IM-0285-0001.jpeg'
sample_image_path_2 = test_path / 'NORMAL' / 'NORMAL2-IM-0378-0001.jpeg'
sample_image_path_3 = test_path / 'NORMAL' / 'NORMAL2-IM-0332-0001.jpeg'
sample_image_path_4 = test_path / 'PNEUMONIA' / 'person109_bacteria_528.jpeg'
sample_image_path_5 = test_path / 'PNEUMONIA' / 'person1675_virus_2891.jpeg'
sample_image_path_6 = test_path / 'PNEUMONIA' / 'person96_bacteria_465.jpeg'

# %%
import scipy
import sys
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# %%
def pretrained_path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = load_img(img_path, target_size=(128, 128), color_mode='grayscale')
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    x = np.expand_dims(x, axis=0)
    # convert RGB -> BGR, subtract mean ImageNet pixel, and return 4D tensor
    return x

def get_ResNet():
    # define ResNet50 model
    model = load_model('checkpoint_archive.h5', custom_objects={'weighted_binary_crossentropy':weighted_binary_crossentropy})
    
    # get AMP layer weights
    conv_weights = model.layers[-3].get_weights()[0]
    
    dense_weights = model.layers[-1].get_weights()[0]
    # extract wanted output
    ResNet_model = Model(inputs=model.input, 
                         outputs=[model.layers[-6].output, model.layers[-3].output, model.layers[-1].output])
    return ResNet_model, conv_weights, dense_weights
    
def ResNet_CAM(img_path, model, conv_weights, dense_weights):
    # get filtered images from convolutional output + model prediction vector
    last_conv_output, pred_vec, prediction = model.predict(pretrained_path_to_tensor(img_path))
    # change dimensions of last convolutional outpu tto 7 x 7 x 2048
    last_conv_output = np.squeeze(last_conv_output) 
    # bilinear upsampling to resize each filtered image to size of original image
    mat_for_mult = scipy.ndimage.zoom(last_conv_output, (18, 18, 1), order=1) # dim: 224 x 224 x 2048

    
    if prediction > 0.5:
        prediction = 1
    else:
        prediction = 0

#     # get AMP layer weights
#     dense_weights = dense_weights[:, prediction] # dim: (2048,) 
    
    first_output = np.dot(conv_weights, dense_weights)

    
    # get class activation map for object class that is predicted to be in the image
    final_output = np.dot(mat_for_mult.reshape((126*126, 448)), first_output).reshape(126,126) # dim: 224 x 224
    # return class activation map
    return final_output, prediction
    
def plot_ResNet_CAM(img_path, ax, model, conv_weights, dense_weights):
    
    im = load_img(img_path, target_size=(126, 126), color_mode='grayscale')
    
    ax[0].imshow(im, cmap='gray', vmin=0, vmax=255)
    ax[1].imshow(im, alpha=0.5, cmap='gray', vmin=0, vmax=255)
    # get class activation map
    CAM, pred = ResNet_CAM(img_path, model, conv_weights, dense_weights)
    # plot class activation map
    ax[1].imshow(CAM, cmap='jet', alpha=0.5)

    if pred == 1:
        classification = 'Pneumonia'
    else:
        classification = 'Normal'
    ax[1].set_title("Classified: %s" % (classification))

ResNet_model, conv_weights, dense_weights = get_ResNet()

# %%
fig, ax = plt.subplots(1,2)
CAM = plot_ResNet_CAM(sample_image_path_1, ax, ResNet_model, conv_weights, dense_weights)
plt.show()

# %%
fig, ax = plt.subplots(1,2)
CAM = plot_ResNet_CAM(sample_image_path_1, ax, ResNet_model, conv_weights, dense_weights)
plt.show()

# %%
fig, ax = plt.subplots(1,2)
CAM = plot_ResNet_CAM(sample_image_path_5, ax, ResNet_model, conv_weights, dense_weights)
plt.show()
